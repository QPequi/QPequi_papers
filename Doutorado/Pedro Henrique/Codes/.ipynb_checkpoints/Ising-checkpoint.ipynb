# %%
using ITensors
using ITensorTDVP
using PyCall
np = pyimport("numpy")

# ==============================================================================
# TDVP FOR ISING
# ==============================================================================

function H_ising(sites, h)
    N = length(sites)    
    os = OpSum()
    for j in 1:(N - 1)
        os += -1, "X", j, "X", j + 1
        os += -h, "Z", j
    end
    os += -1, "X", 1, "X", N
    os += -h, "Z", N
    return MPO(os, sites)
end

function Sx(n) #
    os = OpSum()
    for j in 1:n
        os += +1,"Sx", j
    end
    return MPO(os, sites)
end

N = 10
sites = siteinds("S=1/2", N)
psi0 = productMPS(sites, n -> "X+")


dt = 0.1
Nsteps = 1500
χ = 200
h = np.linspace(0,4,30)
Sz_t = zeros(Nsteps) #Stores the total magnetization at each time step
Sz_av = zeros(length(h)) #Stores the averaged magnetization values

tdvp_kwargs = (time_step=-1im*dt, normalize=false, maxdim=χ, cutoff=1.0e-8, solver_backend="exponentiate")


for i in 1:length(h)
    
    psi_previous = psi0
    H = H_ising(sites, h[i])
    
    for t in 1:Nsteps
    
        psi_current = tdvp(H, psi_previous, -1im*dt; tdvp_kwargs)
        
        Sz_t[t] = real(inner(psi_current', Sx(N), psi_current))
        
        psi_previous = psi_current
    end
    
    Sz_av[i] = (1/(Nsteps*dt))*np.trapz(Sz_t, np.linspace(0, Nsteps*dt, Nsteps))
        
end

np.savetxt("Magnetization_Ising_N100.txt", Sz_av)
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] Array
#     @ ./boot.jl:489 [inlined]
#   [2] similar
#     @ ~/.julia/packages/NDTensors/voe3z/src/abstractarray/similar.jl:8 [inlined]
#   [3] similar
#     @ ~/.julia/packages/NDTensors/voe3z/src/tensorstorage/similar.jl:40 [inlined]
#   [4] similar
#     @ ~/.julia/packages/NDTensors/voe3z/src/tensor/similar.jl:22 [inlined]
#   [5] contraction_output
#     @ ~/.julia/packages/NDTensors/voe3z/src/dense/tensoralgebra/contract.jl:3 [inlined]
#   [6] contraction_output
#     @ ~/.julia/packages/NDTensors/voe3z/src/tensoralgebra/generic_tensor_operations.jl:47 [inlined]
#   [7] contract(tensor1::NDTensors.DenseTensor{ComplexF64, 4, NTuple{4, Index{Int64}}, NDTensors.Dense{ComplexF64, Vector{ComplexF64}}}, labelstensor1::NTuple{4, Int64}, tensor2::NDTensors.DenseTensor{ComplexF64, 3, Tuple{Index{Int64}, Index{Int64}, Index{Int64}}, NDTensors.Dense{ComplexF64, Vector{ComplexF64}}}, labelstensor2::Tuple{Int64, Int64, Int64}, labelsoutput_tensor::NTuple{5, Int64})
#     @ NDTensors ~/.julia/packages/NDTensors/voe3z/src/tensoralgebra/generic_tensor_operations.jl:93
#   [8] contract(::Type{NDTensors.CanContract{NDTensors.DenseTensor{ComplexF64, 4, NTuple{4, Index{Int64}}, NDTensors.Dense{ComplexF64, Vector{ComplexF64}}}, NDTensors.DenseTensor{ComplexF64, 3, Tuple{Index{Int64}, Index{Int64}, Index{Int64}}, NDTensors.Dense{ComplexF64, Vector{ComplexF64}}}}}, tensor1::NDTensors.DenseTensor{ComplexF64, 4, NTuple{4, Index{Int64}}, NDTensors.Dense{ComplexF64, Vector{ComplexF64}}}, labels_tensor1::NTuple{4, Int64}, tensor2::NDTensors.DenseTensor{ComplexF64, 3, Tuple{Index{Int64}, Index{Int64}, Index{Int64}}, NDTensors.Dense{ComplexF64, Vector{ComplexF64}}}, labels_tensor2::Tuple{Int64, Int64, Int64})
#     @ NDTensors ~/.julia/packages/NDTensors/voe3z/src/tensoralgebra/generic_tensor_operations.jl:76
#   [9] contract
#     @ ~/.julia/packages/SimpleTraits/l1ZsK/src/SimpleTraits.jl:331 [inlined]
#  [10] _contract(A::NDTensors.DenseTensor{ComplexF64, 4, NTuple{4, Index{Int64}}, NDTensors.Dense{ComplexF64, Vector{ComplexF64}}}, B::NDTensors.DenseTensor{ComplexF64, 3, Tuple{Index{Int64}, Index{Int64}, Index{Int64}}, NDTensors.Dense{ComplexF64, Vector{ComplexF64}}})
#     @ ITensors ~/.julia/packages/ITensors/w2KHv/src/tensor_operations/tensor_algebra.jl:3
#  [11] _contract(A::ITensor, B::ITensor)
#     @ ITensors ~/.julia/packages/ITensors/w2KHv/src/tensor_operations/tensor_algebra.jl:9
#  [12] contract(A::ITensor, B::ITensor)
#     @ ITensors ~/.julia/packages/ITensors/w2KHv/src/tensor_operations/tensor_algebra.jl:104
#  [13] *
#     @ ~/.julia/packages/ITensors/w2KHv/src/tensor_operations/tensor_algebra.jl:91 [inlined]
#  [14] contract(P::ProjMPO, v::ITensor)
#     @ ITensors ~/.julia/packages/ITensors/w2KHv/src/mps/abstractprojmpo.jl:51
#  [15] product(P::ProjMPO, v::ITensor)
#     @ ITensors ~/.julia/packages/ITensors/w2KHv/src/mps/abstractprojmpo.jl:71
#  [16] AbstractProjMPO
#     @ ~/.julia/packages/ITensors/w2KHv/src/mps/abstractprojmpo.jl:87 [inlined]
#  [17] apply
#     @ ~/.julia/packages/KrylovKit/diNbc/src/apply.jl:2 [inlined]
#  [18] lanczosrecurrence(operator::ProjMPO, V::KrylovKit.OrthonormalBasis{ITensor}, β::Float64, orth::KrylovKit.ModifiedGramSchmidt2)
#     @ KrylovKit ~/.julia/packages/KrylovKit/diNbc/src/factorizations/lanczos.jl:315
#  [19] expand!(iter::KrylovKit.LanczosIterator{ProjMPO, ITensor, KrylovKit.ModifiedGramSchmidt2}, state::KrylovKit.LanczosFactorization{ITensor, Float64}; verbosity::Int64)
#     @ KrylovKit ~/.julia/packages/KrylovKit/diNbc/src/factorizations/lanczos.jl:248
#  [20] expintegrator(A::ProjMPO, t::ComplexF64, u::Tuple{ITensor, ITensor}, alg::KrylovKit.Lanczos{KrylovKit.ModifiedGramSchmidt2, Float64})
#     @ KrylovKit ~/.julia/packages/KrylovKit/diNbc/src/matrixfun/expintegrator.jl:267
#  [21] expintegrator
#     @ ~/.julia/packages/KrylovKit/diNbc/src/matrixfun/expintegrator.jl:106 [inlined]
#  [22] expintegrator(::ProjMPO, ::ComplexF64, ::ITensor; kwargs::Base.Pairs{Symbol, Real, NTuple{7, Symbol}, NamedTuple{(:ishermitian, :issymmetric, :tol, :krylovdim, :maxiter, :verbosity, :eager), Tuple{Bool, Bool, Float64, Int64, Int64, Int64, Bool}}})
#     @ KrylovKit ~/.julia/packages/KrylovKit/diNbc/src/matrixfun/expintegrator.jl:102
#  [23] expintegrator
#     @ ~/.julia/packages/KrylovKit/diNbc/src/matrixfun/expintegrator.jl:98 [inlined]
#  [24] #exponentiate#82
#     @ ~/.julia/packages/KrylovKit/diNbc/src/matrixfun/exponentiate.jl:79 [inlined]
#  [25] exponentiate
#     @ ~/.julia/packages/KrylovKit/diNbc/src/matrixfun/exponentiate.jl:79 [inlined]
#  [26] solver
#     @ ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp.jl:12 [inlined]
#  [27] solver
#     @ ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp.jl:2 [inlined]
#  [28] tdvp_site_update!(nsite_val::Val{2}, reverse_step_val::Val{true}, solver::ITensorTDVP.var"#solver#34"{ITensorTDVP.var"#solver#33#35"{Base.Pairs{Symbol, NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}, Tuple{Symbol}, NamedTuple{(:tdvp_kwargs,), Tuple{NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}}}}}}, PH::ProjMPO, psi::MPS, b::Int64; current_time::ComplexF64, outputlevel::Int64, time_step::ComplexF64, normalize::Bool, direction::Base.Order.ReverseOrdering{Base.Order.ForwardOrdering}, noise::Float64, which_decomp::Nothing, svd_alg::String, cutoff::Float64, maxdim::Int64, mindim::Int64, maxtruncerr::Float64)
#     @ ITensorTDVP ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_step.jl:356
#  [29] tdvp_site_update!(solver::ITensorTDVP.var"#solver#34"{ITensorTDVP.var"#solver#33#35"{Base.Pairs{Symbol, NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}, Tuple{Symbol}, NamedTuple{(:tdvp_kwargs,), Tuple{NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}}}}}}, PH::ProjMPO, psi::MPS, b::Int64; nsite::Int64, reverse_step::Bool, current_time::ComplexF64, outputlevel::Int64, time_step::ComplexF64, normalize::Bool, direction::Base.Order.ReverseOrdering{Base.Order.ForwardOrdering}, noise::Float64, which_decomp::Nothing, svd_alg::String, cutoff::Float64, maxdim::Int64, mindim::Int64, maxtruncerr::Float64)
#     @ ITensorTDVP ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_step.jl:157
#  [30] tdvp_sweep(direction::Base.Order.ReverseOrdering{Base.Order.ForwardOrdering}, solver::Function, PH::ProjMPO, time_step::ComplexF64, psi::MPS; kwargs::Base.Pairs{Symbol, Any, NTuple{8, Symbol}, NamedTuple{(:current_time, :tdvp_kwargs, :reverse_step, :sweep, :maxdim, :mindim, :cutoff, :noise), Tuple{ComplexF64, NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}, Bool, Int64, Int64, Int64, Float64, Float64}}})
#     @ ITensorTDVP ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_step.jl:80
#  [31] tdvp_step(order::ITensorTDVP.TDVPOrder{2, Base.Order.ForwardOrdering()}, solver::Function, PH::ProjMPO, time_step::ComplexF64, psi::MPS; current_time::Float64, kwargs::Base.Pairs{Symbol, Any, NTuple{7, Symbol}, NamedTuple{(:tdvp_kwargs, :reverse_step, :sweep, :maxdim, :mindim, :cutoff, :noise), Tuple{NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}, Bool, Int64, Int64, Int64, Float64, Float64}}})
#     @ ITensorTDVP ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_step.jl:9
#  [32] macro expansion
#     @ ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_generic.jl:84 [inlined]
#  [33] macro expansion
#     @ ./timing.jl:393 [inlined]
#  [34] tdvp(solver::Function, PH::ProjMPO, t::ComplexF64, psi0::MPS; kwargs::Base.Pairs{Symbol, NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}, Tuple{Symbol}, NamedTuple{(:tdvp_kwargs,), Tuple{NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}}}})
#     @ ITensorTDVP ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_generic.jl:83
#  [35] tdvp
#     @ ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_generic.jl:45 [inlined]
#  [36] tdvp(solver::Function, H::MPO, t::ComplexF64, psi0::MPS; kwargs::Base.Pairs{Symbol, NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}, Tuple{Symbol}, NamedTuple{(:tdvp_kwargs,), Tuple{NamedTuple{(:time_step, :normalize, :maxdim, :cutoff, :solver_backend), Tuple{ComplexF64, Bool, Int64, Float64, String}}}}})
#     @ ITensorTDVP ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_generic.jl:150
#  [37] tdvp
#     @ ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp_generic.jl:143 [inlined]
#  [38] #tdvp#41
#     @ ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp.jl:47 [inlined]
#  [39] tdvp
#     @ ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp.jl:46 [inlined]
#  [40] #tdvp#43
#     @ ~/.julia/packages/ITensorTDVP/V1Kco/src/tdvp.jl:55 [inlined]
#  [41] top-level scope
#     @ ./In[1]:52
